# %%
import pandas as pd 

df = pd.DataFrame({
    "data_index": [1, 1, 2],
    "split": ["test_clean", "test_clean", "test_clean"],
    "image_path": ["images/1.jpg", "images/1.jpg", "images/2.jpg"],
    "question": ["Текст вопроса", "Текст вопроса", "Текст вопроса"],
    "answer": ["Текст ответа", "Текст ответа", "Текст ответа"],
    "doc class": ["passport", "passport", "document"],
    "question type": ["Имя", "Фамилия", "Сумма"],
    "answear bbox": ["[10,20,30,40]", "[10,20,30,40]", "[10,20,30,40]"]
})

# %%
# Сохранение DataFrame в формате Markdown
markdown_table = df.to_markdown(index=False)

# Сохранение в файл
with open("datasets.md", "w", encoding="utf-8") as f:
    f.write(markdown_table)
